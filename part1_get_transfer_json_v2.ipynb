# %%
import time
import redis
import json
r = redis.Redis(host='192.168.80.166', port=6379)

# %%
while True:
    city_dict = {"NTPC":"新北", "ZMI":"苗栗", "NTC":"南投"}
    json_list = []
    for city in ["NTPC", "ZMI", "NTC"]:
        for strength in ["strong", "medium", "weak"]:
            run_data = r.hmget("run_"+strength+"_"+city, [city, strength, 'info'])[2].decode()
            if run_data == "Not find the route":
                run_json = [
                            {
                              "type": "flex",
                              "altText": "Flex Message",
                              "contents": {
                                "type": "bubble",
                                "direction": "ltr",
                                "header": {
                                  "type": "box",
                                  "layout": "vertical",
                                  "contents": [
                                    {
                                      "type": "text",
                                      "text": "為您推薦的跑步資訊如下：",
                                      "size": "lg",
                                      "align": "start",
                                      "weight": "bold"
                                    }
                                  ]
                                },
                                "body": {
                                  "type": "box",
                                  "layout": "vertical",
                                  "contents": [
                                    {
                                      "type": "text",
                                      "text": "區域：Not find the route",
                                      "align": "start"
                                    },
                                    {
                                      "type": "text",
                                      "text": "地點：Not find the route",
                                      "align": "start"
                                    },
                                    {
                                      "type": "text",
                                      "text": "里程：Not find the route"
                                    }
                                  ]
                                },
                                "footer": {
                                  "type": "box",
                                  "layout": "horizontal",
                                  "contents": [
                                    {
                                      "type": "button",
                                      "action": {
                                        "type": "uri",
                                        "label": "GPX Download",
                                        "uri": "https://linecorp.com"
                                      }
                                    }
                                  ]
                                }
                              }
                            }
                            ]
                with open('1-4-run-'+strength+'-'+city+'.json','w') as file_object:
                    json.dump(run_json, file_object, indent=2)

            elif isinstance(eval(run_data),dict) == True:
                run_dict = eval(run_data)
                run_json = [
                            {
                              "type": "flex",
                              "altText": "Flex Message",
                              "contents": {
                                "type": "bubble",
                                "direction": "ltr",
                                "header": {
                                  "type": "box",
                                  "layout": "vertical",
                                  "contents": [
                                    {
                                      "type": "text",
                                      "text": "為您推薦的跑步資訊如下：",
                                      "size": "lg",
                                      "align": "start",
                                      "weight": "bold"
                                    }
                                  ]
                                },
                                "body": {
                                  "type": "box",
                                  "layout": "vertical",
                                  "contents": [
                                    {
                                      "type": "text",
                                      "text": "區域：" + run_dict['city'],
                                      "align": "start"
                                    },
                                    {
                                      "type": "text",
                                      "text": "地點：" + run_dict['name'],
                                      "align": "start"
                                    },
                                    {
                                      "type": "text",
                                      "text": "里程：" + run_dict['mileage']
                                    }
                                  ]
                                },
                                "footer": {
                                  "type": "box",
                                  "layout": "horizontal",
                                  "contents": [
                                    {
                                      "type": "button",
                                      "action": {
                                        "type": "uri",
                                        "label": "GPX Download",
                                        "uri": "https://linecorp.com"
                                      }
                                    }
                                  ]
                                }
                              }
                            }
                            ]
                with open('1-4-run-'+strength+'-'+city+'.json','w') as file_object:
                    json.dump(run_json, file_object, indent=2)

            climb_data = r.hmget("climb_"+strength+"_"+city, [city, strength, 'info'])[2].decode()
            if climb_data == "Not find the route" :
                climb_json = [
                            {
                              "type": "flex",
                              "altText": "Flex Message",
                              "contents": {
                                "type": "bubble",
                                "direction": "ltr",
                                "header": {
                                  "type": "box",
                                  "layout": "vertical",
                                  "contents": [
                                    {
                                      "type": "text",
                                      "text": "為您推薦的登山資訊如下：",
                                      "size": "lg",
                                      "align": "start",
                                      "weight": "bold"
                                    }
                                  ]
                                },
                                "body": {
                                  "type": "box",
                                  "layout": "vertical",
                                  "contents": [
                                    {
                                      "type": "text",
                                      "text": "區域：Not find the route",
                                      "align": "start"
                                    },
                                    {
                                      "type": "text",
                                      "text": "地點：Not find the route",
                                      "size": "md",
                                      "align": "start",
                                      "gravity": "top"
                                    },
                                    {
                                      "type": "text",
                                      "text": "里程：Not find the route"
                                    },
                                    {
                                      "type": "text",
                                      "text": "爬升量：Not find the route"
                                    }
                                  ]
                                },
                                "footer": {
                                  "type": "box",
                                  "layout": "horizontal",
                                  "contents": [
                                    {
                                      "type": "button",
                                      "action": {
                                        "type": "uri",
                                        "label": "GPX Download",
                                        "uri": "https://linecorp.com"
                                      }
                                    }
                                  ]
                                }
                              }
                            }
                            ]
                with open('1-4-climb-'+strength+'-'+city+'.json','w') as file_object:
                    json.dump(climb_json, file_object, indent=2)

            elif isinstance(eval(climb_data), dict) == True:
                climb_dict = eval(climb_data)
                climb_json = [
                            {
                              "type": "flex",
                              "altText": "Flex Message",
                              "contents": {
                                "type": "bubble",
                                "direction": "ltr",
                                "header": {
                                  "type": "box",
                                  "layout": "vertical",
                                  "contents": [
                                    {
                                      "type": "text",
                                      "text": "為您推薦的登山資訊如下：",
                                      "size": "lg",
                                      "align": "start",
                                      "weight": "bold"
                                    }
                                  ]
                                },
                                "body": {
                                  "type": "box",
                                  "layout": "vertical",
                                  "contents": [
                                    {
                                      "type": "text",
                                      "text": "區域：" + climb_dict['city'],
                                      "align": "start"
                                    },
                                    {
                                      "type": "text",
                                      "text": "地點：" + climb_dict['name'],
                                      "size": "md",
                                      "align": "start",
                                      "gravity": "top"
                                    },
                                    {
                                      "type": "text",
                                      "text": "里程：" + climb_dict['mileage']
                                    },
                                    {
                                      "type": "text",
                                      "text": "爬升量：" + climb_dict['high']
                                    }
                                  ]
                                },
                                "footer": {
                                  "type": "box",
                                  "layout": "horizontal",
                                  "contents": [
                                    {
                                      "type": "button",
                                      "action": {
                                        "type": "uri",
                                        "label": "GPX Download",
                                        "uri": "https://linecorp.com"
                                      }
                                    }
                                  ]
                                }
                              }
                            }
                            ]
                with open('1-4-climb-'+strength+'-'+city+'.json','w') as file_object:
                    json.dump(climb_json, file_object, indent=2)

            print(city, '|', strength )
            print("run", ":", run_data)
            print("climb", ":", climb_data)
            print('--------------------------------------------------STRENGTH--------------------------------------------------')
            time.sleep(5)
        print('--------------------------------------------------CITY--------------------------------------------------')
        time.sleep(5)
    print('--------------------------------------------------UPDATE--------------------------------------------------')
    time.sleep(5)
# Out:
# NTPC | strong
# run : Not find the route
# climb : {'url': 'https://hiking.biji.co/index.php?q=trail&act=detail&id=1218', 'name': '陽明山東西大縱走(超健腳加強版)', 'score': 5, 'mileage': '39.2公里', 'high': '5~1120公尺', 'level': '高', 'city': '新北市金山區'}
# --------------------------------------------------STRENGTH--------------------------------------------------
# NTPC | medium
# run : {'url': 'https://hiking.biji.co/index.php?q=trail&act=detail&id=669', 'name': '耳空龜山登山步道、磐石古道', 'score': 4, 'mileage': '5.7公里', 'high': '520~588公尺', 'level': '中', 'city': '新北市平溪區'}
# climb : {'url': 'https://hiking.biji.co/index.php?q=trail&act=detail&id=964', 'name': '崩山坑古道', 'score': 5, 'mileage': '6.4公里', 'high': '150~559公尺', 'level': '中', 'city': '新北市雙溪區'}
# --------------------------------------------------STRENGTH--------------------------------------------------
# NTPC | weak
# run : {'url': 'https://hiking.biji.co/index.php?q=trail&act=detail&id=1346', 'name': '雙溪後番子坑溪步道', 'score': 4, 'mileage': '單程0.65公里', 'high': '55~84公尺', 'level': '低', 'city': '新北市雙溪區'}
# climb : {'url': 'https://hiking.biji.co/index.php?q=trail&act=detail&id=82', 'name': '牛寮埔登山步道', 'score': 4, 'mileage': '單程1.6公里', 'high': '224~616公尺', 'level': '低', 'city': '新北市八里區'}
# --------------------------------------------------STRENGTH--------------------------------------------------
