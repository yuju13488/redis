# %%
import random
import time
import redis
import json
r = redis.Redis(host='192.168.80.166', port=6379)

# %%
while True:
    cycling_north1 = eval(r.hmget('cycling_race', ['North', 'Center', 'South', 'East'])[0].decode().split("|")[0])
    if cycling_north1['url'][0:4] != 'http':
        cycling_north1['url'] = 'https://www.google.com/'
    cycling_north2 = eval(r.hmget('cycling_race', ['North', 'Center', 'South', 'East'])[0].decode().split("|")[1])
    if cycling_north2['url'][0:4] != 'http':
        cycling_north2['url'] = 'https://www.google.com/'
    cycling_north3 = eval(r.hmget('cycling_race', ['North', 'Center', 'South', 'East'])[0].decode().split("|")[2])
    if cycling_north3['url'][0:4] != 'http':
        cycling_north3['url'] = 'https://www.google.com/'
    print(cycling_north1, cycling_north2, cycling_north3, sep='\n')
    print('------------------------------------------------------------------')
    cycling_center1 = eval(r.hmget('cycling_race', ['North', 'Center', 'South', 'East'])[1].decode().split("|")[0])
    if cycling_center1['url'][0:4] != 'http':
        cycling_center1['url'] = 'https://www.google.com/'
    cycling_center2 = eval(r.hmget('cycling_race', ['North', 'Center', 'South', 'East'])[1].decode().split("|")[1])
    if cycling_center2['url'][0:4] != 'http':
        cycling_center2['url'] = 'https://www.google.com/'
    cycling_center3 = eval(r.hmget('cycling_race', ['North', 'Center', 'South', 'East'])[1].decode().split("|")[2])
    if cycling_center3['url'][0:4] != 'http':
        cycling_center3['url'] = 'https://www.google.com/'
    print(cycling_center1, cycling_center2, cycling_center3, sep='\n')
    print('------------------------------------------------------------------')
    cycling_south1 = eval(r.hmget('cycling_race', ['North', 'Center', 'South', 'East'])[2].decode().split("|")[0])
    if cycling_south1['url'][0:4] != 'http':
        cycling_south1['url'] = 'https://www.google.com/'
    cycling_south2 = eval(r.hmget('cycling_race', ['North', 'Center', 'South', 'East'])[2].decode().split("|")[1])
    if cycling_south2['url'][0:4] != 'http':
        cycling_south2['url'] = 'https://www.google.com/'
    cycling_south3 = eval(r.hmget('cycling_race', ['North', 'Center', 'South', 'East'])[2].decode().split("|")[2])
    if cycling_south3['url'][0:4] != 'http':
        cycling_south3['url'] = 'https://www.google.com/'
    print(cycling_south1, cycling_south2, cycling_south3, sep='\n')
    print('------------------------------------------------------------------')
    cycling_east1 = eval(r.hmget('cycling_race', ['North', 'Center', 'South', 'East'])[3].decode().split("|")[0])
    if cycling_east1['url'][0:4] != 'http':
        cycling_east1['url'] = 'https://www.google.com/'
    cycling_east2 = eval(r.hmget('cycling_race', ['North', 'Center', 'South', 'East'])[3].decode().split("|")[1])
    if cycling_east2['url'][0:4] != 'http':
        cycling_east2['url'] = 'https://www.google.com/'
    cycling_east3 = eval(r.hmget('cycling_race', ['North', 'Center', 'South', 'East'])[3].decode().split("|")[2])
    if cycling_east3['url'][0:4] != 'http':
        cycling_east3['url'] = 'https://www.google.com/'
    print(cycling_east1, cycling_east2, cycling_east3, sep='\n')
    print('------------------------------------------------------------------')
    run_north1 = eval(r.hmget('running_race', ['North', 'Center', 'South', 'East'])[0].decode().split("|")[0])
    if run_north1['url'][0:4] != 'http':
        run_north1['url'] = 'https://www.google.com/'
    run_north2 = eval(r.hmget('running_race', ['North', 'Center', 'South', 'East'])[0].decode().split("|")[1])
    if run_north2['url'][0:4] != 'http':
        run_north2['url'] = 'https://www.google.com/'
    run_north3 = eval(r.hmget('running_race', ['North', 'Center', 'South', 'East'])[0].decode().split("|")[2])
    if run_north3['url'][0:4] != 'http':
        run_north3['url'] = 'https://www.google.com/'
    print(run_north1, run_north2, run_north3, sep='\n')
    print('------------------------------------------------------------------')
    run_center1 = eval(r.hmget('running_race', ['North', 'Center', 'South', 'East'])[1].decode().split("|")[0])
    if run_center1['url'][0:4] != 'http':
        run_center1['url'] = 'https://www.google.com/'
    run_center2 = eval(r.hmget('running_race', ['North', 'Center', 'South', 'East'])[1].decode().split("|")[1])
    if run_center2['url'][0:4] != 'http':
        run_center2['url'] = 'https://www.google.com/'
    run_center3 = eval(r.hmget('running_race', ['North', 'Center', 'South', 'East'])[1].decode().split("|")[2])
    if run_center3['url'][0:4] != 'http':
        run_center3['url'] = 'https://www.google.com/'
    print(run_center1, run_center2, run_center3, sep='\n')
    print('------------------------------------------------------------------')
    run_south1 = eval(r.hmget('running_race', ['North', 'Center', 'South', 'East'])[2].decode().split("|")[0])
    if run_south1['url'][0:4] != 'http':
        run_south1['url'] = 'https://www.google.com/'
    run_south2 = eval(r.hmget('running_race', ['North', 'Center', 'South', 'East'])[2].decode().split("|")[1])
    if run_south2['url'][0:4] != 'http':
        run_south2['url'] = 'https://www.google.com/'
    run_south3 = eval(r.hmget('running_race', ['North', 'Center', 'South', 'East'])[2].decode().split("|")[2])
    if run_south3['url'][0:4] != 'http':
        run_south3['url'] = 'https://www.google.com/'
    print(run_center1, run_center2, run_center3, sep='\n')
    print('------------------------------------------------------------------')
    run_east1 = eval(r.hmget('running_race', ['North', 'Center', 'South', 'East'])[3].decode().split("|")[0])
    if run_east1['url'][0:4] != 'http':
        run_east1['url'] = 'https://www.google.com/'
    run_east2 = eval(r.hmget('running_race', ['North', 'Center', 'South', 'East'])[3].decode().split("|")[1])
    if run_east2['url'][0:4] != 'http':
        run_east2['url'] = 'https://www.google.com/'
    run_east3 = eval(r.hmget('running_race', ['North', 'Center', 'South', 'East'])[3].decode().split("|")[2])
    if run_east3['url'][0:4] != 'http':
        run_east3['url'] = 'https://www.google.com/'
    print(run_center1, run_center2, run_center3, sep='\n')
    print('-NEW LOOP----------------------------------------------------------------NEW LOOP-')
    
    cycling_north = [
                    {
                      "type": "template",
                      "altText": "this is a carousel template",
                      "template": {
                        "type": "carousel",
                        "actions": [],
                        "columns": [
                          {
                            "title": "賽事1",
                            "text": cycling_north1['name'],
                            "actions": [
                              {
                                "type": "uri",
                                "label": "活動網址",
                                "uri": cycling_north1['url']
                              }
                            ]
                          },
                          {
                            "title": "賽事2",
                            "text": cycling_north2['name'],
                            "actions": [
                              {
                                "type": "uri",
                                "label": "活動網址",
                                "uri": cycling_north2['url']
                              }
                            ]
                          },
                          {
                            "title": "賽事3",
                            "text": cycling_north3['name'],
                            "actions": [
                              {
                                "type": "uri",
                                "label": "活動網址",
                                "uri": cycling_north3['url']
                              }
                            ]
                          }
                        ]
                      }
                    }
                    ]
    with open('2-ride-north.json','w') as file_object:
        json.dump(cycling_north, file_object, indent=2)
        
    cycling_center = [
                    {
                      "type": "template",
                      "altText": "this is a carousel template",
                      "template": {
                        "type": "carousel",
                        "actions": [],
                        "columns": [
                          {
                            "title": "賽事1",
                            "text": cycling_center1['name'],
                            "actions": [
                              {
                                "type": "uri",
                                "label": "活動網址",
                                "uri": cycling_center1['url']
                              }
                            ]
                          },
                          {
                            "title": "賽事2",
                            "text": cycling_center2['name'],
                            "actions": [
                              {
                                "type": "uri",
                                "label": "活動網址",
                                "uri": cycling_center2['url']
                              }
                            ]
                          },
                          {
                            "title": "賽事3",
                            "text": cycling_center3['name'],
                            "actions": [
                              {
                                "type": "uri",
                                "label": "活動網址",
                                "uri": cycling_center3['url']
                              }
                            ]
                          }
                        ]
                      }
                    }
                    ]
    with open('2-ride-center.json','w') as file_object:
        json.dump(cycling_center, file_object, indent=2)
        
    cycling_south = [
                    {
                      "type": "template",
                      "altText": "this is a carousel template",
                      "template": {
                        "type": "carousel",
                        "actions": [],
                        "columns": [
                          {
                            "title": "賽事1",
                            "text": cycling_south1['name'],
                            "actions": [
                              {
                                "type": "uri",
                                "label": "活動網址",
                                "uri": cycling_south1['url']
                              }
                            ]
                          },
                          {
                            "title": "賽事2",
                            "text": cycling_south2['name'],
                            "actions": [
                              {
                                "type": "uri",
                                "label": "活動網址",
                                "uri": cycling_south2['url']
                              }
                            ]
                          },
                          {
                            "title": "賽事3",
                            "text": cycling_south3['name'],
                            "actions": [
                              {
                                "type": "uri",
                                "label": "活動網址",
                                "uri": cycling_south3['url']
                              }
                            ]
                          }
                        ]
                      }
                    }
                    ]
    with open('2-ride-south.json','w') as file_object:
        json.dump(cycling_south, file_object, indent=2)
        
    cycling_east = [
                    {
                      "type": "template",
                      "altText": "this is a carousel template",
                      "template": {
                        "type": "carousel",
                        "actions": [],
                        "columns": [
                          {
                            "title": "賽事1",
                            "text": cycling_east1['name'],
                            "actions": [
                              {
                                "type": "uri",
                                "label": "活動網址",
                                "uri": cycling_east1['url']
                              }
                            ]
                          },
                          {
                            "title": "賽事2",
                            "text": cycling_east2['name'],
                            "actions": [
                              {
                                "type": "uri",
                                "label": "活動網址",
                                "uri": cycling_east2['url']
                              }
                            ]
                          },
                          {
                            "title": "賽事3",
                            "text": cycling_east3['name'],
                            "actions": [
                              {
                                "type": "uri",
                                "label": "活動網址",
                                "uri": cycling_south3['url']
                              }
                            ]
                          }
                        ]
                      }
                    }
                    ]
    with open('2-ride-east.json','w') as file_object:
        json.dump(cycling_east, file_object, indent=2)

    run_north = [
                    {
                      "type": "template",
                      "altText": "this is a carousel template",
                      "template": {
                        "type": "carousel",
                        "actions": [],
                        "columns": [
                          {
                            "title": "賽事1",
                            "text": run_north1['name'],
                            "actions": [
                              {
                                "type": "uri",
                                "label": "活動網址",
                                "uri": run_north1['url']
                              }
                            ]
                          },
                          {
                            "title": "賽事2",
                            "text": run_north2['name'],
                            "actions": [
                              {
                                "type": "uri",
                                "label": "活動網址",
                                "uri": run_north2['url']
                              }
                            ]
                          },
                          {
                            "title": "賽事3",
                            "text": run_north3['name'],
                            "actions": [
                              {
                                "type": "uri",
                                "label": "活動網址",
                                "uri": run_north3['url']
                              }
                            ]
                          }
                        ]
                      }
                    }
                    ]
    with open('2-run-north.json','w') as file_object:
        json.dump(run_north, file_object, indent=2)
        
    run_center = [
                    {
                      "type": "template",
                      "altText": "this is a carousel template",
                      "template": {
                        "type": "carousel",
                        "actions": [],
                        "columns": [
                          {
                            "title": "賽事1",
                            "text": run_center1['name'],
                            "actions": [
                              {
                                "type": "uri",
                                "label": "活動網址",
                                "uri": run_center1['url']
                              }
                            ]
                          },
                          {
                            "title": "賽事2",
                            "text": run_center2['name'],
                            "actions": [
                              {
                                "type": "uri",
                                "label": "活動網址",
                                "uri": run_center2['url']
                              }
                            ]
                          },
                          {
                            "title": "賽事3",
                            "text": run_center3['name'],
                            "actions": [
                              {
                                "type": "uri",
                                "label": "活動網址",
                                "uri": run_center3['url']
                              }
                            ]
                          }
                        ]
                      }
                    }
                    ]
    with open('2-run-center.json','w') as file_object:
        json.dump(run_center, file_object, indent=2)
        
    run_south = [
                    {
                      "type": "template",
                      "altText": "this is a carousel template",
                      "template": {
                        "type": "carousel",
                        "actions": [],
                        "columns": [
                          {
                            "title": "賽事1",
                            "text": run_south1['name'],
                            "actions": [
                              {
                                "type": "uri",
                                "label": "活動網址",
                                "uri": run_south1['url']
                              }
                            ]
                          },
                          {
                            "title": "賽事2",
                            "text": run_south2['name'],
                            "actions": [
                              {
                                "type": "uri",
                                "label": "活動網址",
                                "uri": run_south2['url']
                              }
                            ]
                          },
                          {
                            "title": "賽事3",
                            "text": run_south3['name'],
                            "actions": [
                              {
                                "type": "uri",
                                "label": "活動網址",
                                "uri": run_south3['url']
                              }
                            ]
                          }
                        ]
                      }
                    }
                    ]
    with open('2-run-south.json','w') as file_object:
        json.dump(run_south, file_object, indent=2)
        
    run_east = [
                    {
                      "type": "template",
                      "altText": "this is a carousel template",
                      "template": {
                        "type": "carousel",
                        "actions": [],
                        "columns": [
                          {
                            "title": "賽事1",
                            "text": run_east1['name'],
                            "actions": [
                              {
                                "type": "uri",
                                "label": "活動網址",
                                "uri": run_east1['url']
                              }
                            ]
                          },
                          {
                            "title": "賽事2",
                            "text": run_east2['name'],
                            "actions": [
                              {
                                "type": "uri",
                                "label": "活動網址",
                                "uri": run_east2['url']
                              }
                            ]
                          },
                          {
                            "title": "賽事3",
                            "text": run_east3['name'],
                            "actions": [
                              {
                                "type": "uri",
                                "label": "活動網址",
                                "uri": run_east3['url']
                              }
                            ]
                          }
                        ]
                      }
                    }
                    ]
    with open('2-run-east.json','w') as file_object:
        json.dump(run_east, file_object, indent=2)
    time.sleep(60)
# Out:
# {'type': '自行車', 'name': '2019小惡魔鬥陣騎北宜', 'url': 'https://www.mobile01.com/topicdetail.php?f=287&t=5684981'}
# {'type': '自行車', 'name': '2019不厭五分經典挑戰', 'url': 'http://www.taiwanbike.org/index.php/395-2017-060'}
# {'type': '自行車', 'name': '2019 WPC太平山國際自行車挑戰賽', 'url': 'http://www.bao-ming.com/eb/www/activity_content.php?activitysn=3808'}
# ------------------------------------------------------------------
# {'type': '自行車', 'name': '2019KHS彰化不落119_鄉野騎跡', 'url': 'http://www.flca.tw/?fbclid=IwAR2CM_7bCXczJjYWkv_QMnJI62IrYbpEco-XR6tMXqWdKJ38NjhGuI-pg0Q'}
# {'type': '自行車', 'name': '環大苗栗經典百K挑戰', 'url': 'http://www.taiwanbike.org/index.php/477-2019-4'}
# {'type': '自行車', 'name': '美利達.瑪吉斯盃 2019(第9屆)彰化經典百K Changhua Classic 100單車自我挑戰', 'url': 'https://www.merida.tw/news/cate-75282.htm#cbp=/news-detail/show-330540.htm'}
# ------------------------------------------------------------------
# ...
